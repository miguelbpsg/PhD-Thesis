# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

def select_elements(file_name, num_clusters, mutants):
    # Read the file and process lines in pairs
    with open(file_name, 'r') as file:
        lines = file.readlines()
        categories = []
        values = []
        for i in range(0, len(lines), 2):
            # Remove whitespace and split categories by space
            cats = lines[i].strip().split()
            # Add categories to the main list
            categories.extend(cats)
            # Add associated value if lines are available
            if i + 1 < len(lines):
                values.append(float(lines[i+1].strip()))

    # Get unique categories
    categories = list(set(categories))

    # Create a dictionary to store binary variables and 'Length'
    data = {cat: [] for cat in categories}
    data['Length'] = []

    # Process categories and create binary variables
    for i in range(len(values)):
        for cat in categories:
            if cat in lines[2*i]:
                data[cat].append(1)
            else:
                data[cat].append(0)
        data['Length'].append(values[i] if i < len(values) else None)
    
    for num in range(mutants+1):
        col_name = str(num)
        if col_name not in data:
            data[col_name] = [0] * len(values)
    
    

    # Create DataFrame
    df = pd.DataFrame(data)

    # Normalize data (except the 'Length' column)
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df.drop(columns=['Length']))

    # Apply hierarchical clustering
    cluster = AgglomerativeClustering(n_clusters=num_clusters, metric='euclidean', linkage='ward')
    clusters = cluster.fit_predict(df_scaled)

    # Create a new DataFrame with all variables and the cluster they belong to
    df_with_cluster = df.copy()
    df_with_cluster['Cluster'] = clusters

    # Calculate total length
    total_length = sum(df_with_cluster['Length'])

    # Initialize accumulated length and selected elements
    accumulated_length = 0
    selected_indices = []

    # Select one element from each cluster
    for cluster_id in range(num_clusters):
        cluster_elements = df_with_cluster[df_with_cluster['Cluster'] == cluster_id]
        if len(cluster_elements) > 0:
            smallest_element = cluster_elements['Length'].idxmin()
            accumulated_length += df_with_cluster.loc[smallest_element]['Length']
            # Add the smallest element
            selected_indices.append(smallest_element)

    # Filter the original DataFrame to get the selected elements
    selected_elements = df_with_cluster.loc[selected_indices]

    # Calculate the total number of mutants in all combined columns
    total_mutant_deaths = selected_elements.iloc[:, :-2].sum(axis=0)

    # Calculate the total number of mutants "killed" at least once in any test
    total_mutants_killed = (total_mutant_deaths > 0).sum()

    # Calculate the percentage of mutants killed by any test
    percentage_mutants_killed = (total_mutants_killed / len(total_mutant_deaths)) * 100

    print("Total number of mutants 'killed' at least once:", total_mutants_killed)
    print("Percentage of mutants 'killed' by any test:", percentage_mutants_killed)

    return 100-percentage_mutants_killed, accumulated_length

# %%
# Example usage
for file in range(0,9):
    file_name = 'inputs/Elems_' + str(file) + '.txt'
    mutants_name = 'inputs/Muts_' + str(file) + '.txt'
    with open(mutants_name, 'r') as muts_file:
        mutants_size = int(muts_file.readline().strip('\n'))
    for num_clusters in range(2,31):        
        ms, length = select_elements(file_name, num_clusters, mutants_size)
        print(length, ";", ms)
    print()
# Out:
# Total number of mutants 'killed' at least once: 60
# Percentage of mutants 'killed' by any test: 14.962593516209477
# 6.0 ; 85.03740648379052
# Total number of mutants 'killed' at least once: 111
# Percentage of mutants 'killed' by any test: 27.680798004987533
# 12.0 ; 72.31920199501246
# Total number of mutants 'killed' at least once: 171
# Percentage of mutants 'killed' by any test: 42.643391521197
# 22.0 ; 57.356608478803
# Total number of mutants 'killed' at least once: 208
# Percentage of mutants 'killed' by any test: 51.87032418952619
# 32.0 ; 48.12967581047381
# Total number of mutants 'killed' at least once: 242
# Percentage of mutants 'killed' by any test: 60.349127182044896
# 41.0 ; 39.650872817955104
# Total number of mutants 'killed' at least once: 269
# Percentage of mutants 'killed' by any test: 67.08229426433915
# 48.0 ; 32.917705735660846
# Total number of mutants 'killed' at least once: 274
# Percentage of mutants 'killed' by any test: 68.3291770573566
# 56.0 ; 31.670822942643397
# Total number of mutants 'killed' at least once: 287
# Percentage of mutants 'killed' by any test: 71.571072319202
# 66.0 ; 28.428927680797997
# Total number of mutants 'killed' at least once: 307
# Percentage of mutants 'killed' by any test: 76.55860349127181
# 76.0 ; 23.44139650872819
# Total number of mutants 'killed' at least once: 310
# Percentage of mutants 'killed' by any test: 77.3067331670823
# 85.0 ; 22.6932668329177
# Total number of mutants 'killed' at least once: 317
# Percentage of mutants 'killed' by any test: 79.05236907730672
# 90.0 ; 20.94763092269328
# Total number of mutants 'killed' at least once: 320
# Percentage of mutants 'killed' by any test: 79.80049875311721
# 100.0 ; 20.19950124688279
# Total number of mutants 'killed' at least once: 320
# Percentage of mutants 'killed' by any test: 79.80049875311721
# 110.0 ; 20.19950124688279
# Total number of mutants 'killed' at least once: 320
# Percentage of mutants 'killed' by any test: 79.80049875311721
# 113.0 ; 20.19950124688279
# Total number of mutants 'killed' at least once: 321
# Percentage of mutants 'killed' by any test: 80.0498753117207
# 119.0 ; 19.950124688279303
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 129.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 139.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 141.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 150.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 152.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 157.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 167.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 169.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 171.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 173.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 177.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 179.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 181.0 ; 19.451371571072315
# Total number of mutants 'killed' at least once: 323
# Percentage of mutants 'killed' by any test: 80.54862842892769
# 182.0 ; 19.451371571072315
#
# Total number of mutants 'killed' at least once: 82
# Percentage of mutants 'killed' by any test: 13.643926788685523
# 7.0 ; 86.35607321131448
# Total number of mutants 'killed' at least once: 184
# Percentage of mutants 'killed' by any test: 30.615640599001665
# 17.0 ; 69.38435940099833
# Total number of mutants 'killed' at least once: 231
# Percentage of mutants 'killed' by any test: 38.43594009983361
# 24.0 ; 61.56405990016639
# Total number of mutants 'killed' at least once: 289
# Percentage of mutants 'killed' by any test: 48.0865224625624
# 33.0 ; 51.9134775374376
# Total number of mutants 'killed' at least once: 328
# Percentage of mutants 'killed' by any test: 54.57570715474209
# 43.0 ; 45.42429284525791
# Total number of mutants 'killed' at least once: 367
# Percentage of mutants 'killed' by any test: 61.064891846921796
# 50.0 ; 38.935108153078204
# Total number of mutants 'killed' at least once: 396
# Percentage of mutants 'killed' by any test: 65.89018302828619
# 60.0 ; 34.10981697171381
# Total number of mutants 'killed' at least once: 415
# Percentage of mutants 'killed' by any test: 69.05158069883528
# 70.0 ; 30.94841930116472
# Total number of mutants 'killed' at least once: 432
# Percentage of mutants 'killed' by any test: 71.8801996672213
# 80.0 ; 28.119800332778695
# Total number of mutants 'killed' at least once: 432
# Percentage of mutants 'killed' by any test: 71.8801996672213
# 83.0 ; 28.119800332778695
# Total number of mutants 'killed' at least once: 460
# Percentage of mutants 'killed' by any test: 76.53910149750416
# 93.0 ; 23.460898502495837
# Total number of mutants 'killed' at least once: 479
# Percentage of mutants 'killed' by any test: 79.70049916805324
# 103.0 ; 20.29950083194676
# Total number of mutants 'killed' at least once: 490
# Percentage of mutants 'killed' by any test: 81.53078202995009
# 107.0 ; 18.46921797004991
# Total number of mutants 'killed' at least once: 500
# Percentage of mutants 'killed' by any test: 83.19467554076539
# 117.0 ; 16.805324459234612
# Total number of mutants 'killed' at least once: 513
# Percentage of mutants 'killed' by any test: 85.35773710482529
# 127.0 ; 14.64226289517471
# Total number of mutants 'killed' at least once: 513
# Percentage of mutants 'killed' by any test: 85.35773710482529
# 132.0 ; 14.64226289517471
# Total number of mutants 'killed' at least once: 523
# Percentage of mutants 'killed' by any test: 87.0216306156406
# 142.0 ; 12.978369384359397
# Total number of mutants 'killed' at least once: 533
# Percentage of mutants 'killed' by any test: 88.6855241264559
# 150.0 ; 11.314475873544097
# Total number of mutants 'killed' at least once: 533
# Percentage of mutants 'killed' by any test: 88.6855241264559
# 160.0 ; 11.314475873544097
# Total number of mutants 'killed' at least once: 542
# Percentage of mutants 'killed' by any test: 90.18302828618968
# 170.0 ; 9.816971713810318
# Total number of mutants 'killed' at least once: 549
# Percentage of mutants 'killed' by any test: 91.34775374376039
# 180.0 ; 8.652246256239607
# Total number of mutants 'killed' at least once: 550
# Percentage of mutants 'killed' by any test: 91.51414309484193
# 185.0 ; 8.485856905158073
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 195.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 204.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 210.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 215.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 224.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 228.0 ; 8.319467554076539
# Total number of mutants 'killed' at least once: 551
# Percentage of mutants 'killed' by any test: 91.68053244592346
# 236.0 ; 8.319467554076539
#
# Total number of mutants 'killed' at least once: 52
# Percentage of mutants 'killed' by any test: 6.491885143570538
# 5.0 ; 93.50811485642946
# Total number of mutants 'killed' at least once: 132
# Percentage of mutants 'killed' by any test: 16.479400749063668
# 12.0 ; 83.52059925093633
# Total number of mutants 'killed' at least once: 213
# Percentage of mutants 'killed' by any test: 26.591760299625467
# 22.0 ; 73.40823970037454
# Total number of mutants 'killed' at least once: 277
# Percentage of mutants 'killed' by any test: 34.581772784019975
# 32.0 ; 65.41822721598002
# Total number of mutants 'killed' at least once: 321
# Percentage of mutants 'killed' by any test: 40.074906367041194
# 38.0 ; 59.925093632958806
# Total number of mutants 'killed' at least once: 395
# Percentage of mutants 'killed' by any test: 49.313358302122346
# 48.0 ; 50.686641697877654
# Total number of mutants 'killed' at least once: 434
# Percentage of mutants 'killed' by any test: 54.18227215980025
# 55.0 ; 45.81772784019975
# Total number of mutants 'killed' at least once: 483
# Percentage of mutants 'killed' by any test: 60.2996254681648
# 65.0 ; 39.7003745318352
# Total number of mutants 'killed' at least once: 515
# Percentage of mutants 'killed' by any test: 64.29463171036205
# 72.0 ; 35.705368289637946
# Total number of mutants 'killed' at least once: 532
# Percentage of mutants 'killed' by any test: 66.41697877652933
# 82.0 ; 33.583021223470666
# Total number of mutants 'killed' at least once: 553
# Percentage of mutants 'killed' by any test: 69.03870162297129
# 89.0 ; 30.96129837702871
# Total number of mutants 'killed' at least once: 582
# Percentage of mutants 'killed' by any test: 72.65917602996255
# 98.0 ; 27.340823970037448
# Total number of mutants 'killed' at least once: 620
# Percentage of mutants 'killed' by any test: 77.40324594257179
# 108.0 ; 22.596754057428214
# Total number of mutants 'killed' at least once: 639
# Percentage of mutants 'killed' by any test: 79.7752808988764
# 114.0 ; 20.224719101123597
# Total number of mutants 'killed' at least once: 669
# Percentage of mutants 'killed' by any test: 83.52059925093633
# 124.0 ; 16.47940074906367
# Total number of mutants 'killed' at least once: 689
# Percentage of mutants 'killed' by any test: 86.01747815230961
# 134.0 ; 13.982521847690393
# Total number of mutants 'killed' at least once: 708
# Percentage of mutants 'killed' by any test: 88.38951310861424
# 140.0 ; 11.610486891385762
# Total number of mutants 'killed' at least once: 727
# Percentage of mutants 'killed' by any test: 90.76154806491886
# 150.0 ; 9.238451935081144
# Total number of mutants 'killed' at least once: 729
# Percentage of mutants 'killed' by any test: 91.01123595505618
# 160.0 ; 8.98876404494382
# Total number of mutants 'killed' at least once: 739
# Percentage of mutants 'killed' by any test: 92.25967540574283
# 170.0 ; 7.740324594257174
# Total number of mutants 'killed' at least once: 740
# Percentage of mutants 'killed' by any test: 92.38451935081149
# 177.0 ; 7.6154806491885125
# Total number of mutants 'killed' at least once: 750
# Percentage of mutants 'killed' by any test: 93.63295880149812
# 187.0 ; 6.36704119850188
# Total number of mutants 'killed' at least once: 750
# Percentage of mutants 'killed' by any test: 93.63295880149812
# 197.0 ; 6.36704119850188
# Total number of mutants 'killed' at least once: 750
# Percentage of mutants 'killed' by any test: 93.63295880149812
# 200.0 ; 6.36704119850188
# Total number of mutants 'killed' at least once: 760
# Percentage of mutants 'killed' by any test: 94.88139825218477
# 210.0 ; 5.118601747815234
# Total number of mutants 'killed' at least once: 760
# Percentage of mutants 'killed' by any test: 94.88139825218477
# 220.0 ; 5.118601747815234
# Total number of mutants 'killed' at least once: 770
# Percentage of mutants 'killed' by any test: 96.12983770287141
# 224.0 ; 3.870162297128587
# Total number of mutants 'killed' at least once: 770
# Percentage of mutants 'killed' by any test: 96.12983770287141
# 234.0 ; 3.870162297128587
# Total number of mutants 'killed' at least once: 770
# Percentage of mutants 'killed' by any test: 96.12983770287141
# 241.0 ; 3.870162297128587
#
# Total number of mutants 'killed' at least once: 276
# Percentage of mutants 'killed' by any test: 11.035585765693723
# 8.0 ; 88.96441423430628
# Total number of mutants 'killed' at least once: 545
# Percentage of mutants 'killed' by any test: 21.79128348660536
# 18.0 ; 78.20871651339465
# Total number of mutants 'killed' at least once: 894
# Percentage of mutants 'killed' by any test: 35.74570171931227
# 32.0 ; 64.25429828068772
# Total number of mutants 'killed' at least once: 1474
# Percentage of mutants 'killed' by any test: 58.93642542982806
# 55.0 ; 41.06357457017194
# Total number of mutants 'killed' at least once: 1580
# Percentage of mutants 'killed' by any test: 63.17473010795682
# 73.0 ; 36.82526989204318
# Total number of mutants 'killed' at least once: 1689
# Percentage of mutants 'killed' by any test: 67.53298680527789
# 89.0 ; 32.467013194722114
# Total number of mutants 'killed' at least once: 1738
# Percentage of mutants 'killed' by any test: 69.4922031187525
# 98.0 ; 30.5077968812475
# Total number of mutants 'killed' at least once: 1763
# Percentage of mutants 'killed' by any test: 70.49180327868852
# 109.0 ; 29.508196721311478
# Total number of mutants 'killed' at least once: 1895
# Percentage of mutants 'killed' by any test: 75.76969212315075
# 134.0 ; 24.230307876849253
# Total number of mutants 'killed' at least once: 2012
# Percentage of mutants 'killed' by any test: 80.44782087165134
# 156.0 ; 19.552179128348655
# Total number of mutants 'killed' at least once: 2090
# Percentage of mutants 'killed' by any test: 83.56657337065174
# 178.0 ; 16.43342662934826
# Total number of mutants 'killed' at least once: 2115
# Percentage of mutants 'killed' by any test: 84.56617353058776
# 186.0 ; 15.433826469412239
# Total number of mutants 'killed' at least once: 2211
# Percentage of mutants 'killed' by any test: 88.4046381447421
# 205.0 ; 11.595361855257906
# Total number of mutants 'killed' at least once: 2285
# Percentage of mutants 'killed' by any test: 91.36345461815274
# 227.0 ; 8.636545381847256
# Total number of mutants 'killed' at least once: 2311
# Percentage of mutants 'killed' by any test: 92.4030387844862
# 252.0 ; 7.596961215513801
# Total number of mutants 'killed' at least once: 2362
# Percentage of mutants 'killed' by any test: 94.44222311075569
# 268.0 ; 5.557776889244309
# Total number of mutants 'killed' at least once: 2387
# Percentage of mutants 'killed' by any test: 95.44182327069173
# 281.0 ; 4.558176729308272
# Total number of mutants 'killed' at least once: 2414
# Percentage of mutants 'killed' by any test: 96.52139144342263
# 306.0 ; 3.4786085565773703
# Total number of mutants 'killed' at least once: 2439
# Percentage of mutants 'killed' by any test: 97.52099160335865
# 331.0 ; 2.4790083966413476
# Total number of mutants 'killed' at least once: 2439
# Percentage of mutants 'killed' by any test: 97.52099160335865
# 356.0 ; 2.4790083966413476
# Total number of mutants 'killed' at least once: 2462
# Percentage of mutants 'killed' by any test: 98.4406237504998
# 381.0 ; 1.559376249500204
# Total number of mutants 'killed' at least once: 2462
# Percentage of mutants 'killed' by any test: 98.4406237504998
# 385.0 ; 1.559376249500204
# Total number of mutants 'killed' at least once: 2463
# Percentage of mutants 'killed' by any test: 98.48060775689724
# 410.0 ; 1.5193922431027573
# Total number of mutants 'killed' at least once: 2463
# Percentage of mutants 'killed' by any test: 98.48060775689724
# 435.0 ; 1.5193922431027573
# Total number of mutants 'killed' at least once: 2463
# Percentage of mutants 'killed' by any test: 98.48060775689724
# 457.0 ; 1.5193922431027573
# Total number of mutants 'killed' at least once: 2463
# Percentage of mutants 'killed' by any test: 98.48060775689724
# 475.0 ; 1.5193922431027573
# Total number of mutants 'killed' at least once: 2467
# Percentage of mutants 'killed' by any test: 98.640543782487
# 494.0 ; 1.3594562175129994
# Total number of mutants 'killed' at least once: 2467
# Percentage of mutants 'killed' by any test: 98.640543782487
# 519.0 ; 1.3594562175129994
# Total number of mutants 'killed' at least once: 2467
# Percentage of mutants 'killed' by any test: 98.640543782487
# 535.0 ; 1.3594562175129994
#
# Total number of mutants 'killed' at least once: 384
# Percentage of mutants 'killed' by any test: 10.237270061316982
# 10.0 ; 89.76272993868302
# Total number of mutants 'killed' at least once: 1014
# Percentage of mutants 'killed' by any test: 27.032791255665156
# 34.0 ; 72.96720874433484
# Total number of mutants 'killed' at least once: 1174
# Percentage of mutants 'killed' by any test: 31.298320447880567
# 44.0 ; 68.70167955211943
# Total number of mutants 'killed' at least once: 1256
# Percentage of mutants 'killed' by any test: 33.48440415889096
# 49.0 ; 66.51559584110905
# Total number of mutants 'killed' at least once: 1622
# Percentage of mutants 'killed' by any test: 43.24180218608371
# 64.0 ; 56.75819781391629
# Total number of mutants 'killed' at least once: 1887
# Percentage of mutants 'killed' by any test: 50.306584910690475
# 77.0 ; 49.693415089309525
# Total number of mutants 'killed' at least once: 2134
# Percentage of mutants 'killed' by any test: 56.89149560117303
# 90.0 ; 43.10850439882697
# Total number of mutants 'killed' at least once: 2383
# Percentage of mutants 'killed' by any test: 63.52972540655825
# 115.0 ; 36.47027459344175
# Total number of mutants 'killed' at least once: 2458
# Percentage of mutants 'killed' by any test: 65.52919221540922
# 129.0 ; 34.470807784590775
# Total number of mutants 'killed' at least once: 2555
# Percentage of mutants 'killed' by any test: 68.11516928818982
# 146.0 ; 31.88483071181018
# Total number of mutants 'killed' at least once: 2629
# Percentage of mutants 'killed' by any test: 70.08797653958945
# 156.0 ; 29.912023460410552
# Total number of mutants 'killed' at least once: 2799
# Percentage of mutants 'killed' by any test: 74.62010130631832
# 181.0 ; 25.37989869368168
# Total number of mutants 'killed' at least once: 2922
# Percentage of mutants 'killed' by any test: 77.89922687283392
# 206.0 ; 22.10077312716608
# Total number of mutants 'killed' at least once: 3022
# Percentage of mutants 'killed' by any test: 80.56518261796855
# 222.0 ; 19.434817382031454
# Total number of mutants 'killed' at least once: 3129
# Percentage of mutants 'killed' by any test: 83.4177552652626
# 240.0 ; 16.5822447347374
# Total number of mutants 'killed' at least once: 3180
# Percentage of mutants 'killed' by any test: 84.77739269528126
# 258.0 ; 15.222607304718736
# Total number of mutants 'killed' at least once: 3235
# Percentage of mutants 'killed' by any test: 86.24366835510531
# 276.0 ; 13.756331644894686
# Total number of mutants 'killed' at least once: 3235
# Percentage of mutants 'killed' by any test: 86.24366835510531
# 290.0 ; 13.756331644894686
# Total number of mutants 'killed' at least once: 3258
# Percentage of mutants 'killed' by any test: 86.85683817648628
# 296.0 ; 13.143161823513722
# Total number of mutants 'killed' at least once: 3282
# Percentage of mutants 'killed' by any test: 87.49666755531858
# 321.0 ; 12.50333244468142
# Total number of mutants 'killed' at least once: 3352
# Percentage of mutants 'killed' by any test: 89.36283657691281
# 330.0 ; 10.637163423087188
# Total number of mutants 'killed' at least once: 3401
# Percentage of mutants 'killed' by any test: 90.66915489202879
# 354.0 ; 9.330845107971214
# Total number of mutants 'killed' at least once: 3426
# Percentage of mutants 'killed' by any test: 91.33564382831246
# 379.0 ; 8.664356171687544
# Total number of mutants 'killed' at least once: 3477
# Percentage of mutants 'killed' by any test: 92.69528125833111
# 404.0 ; 7.304718741668893
# Total number of mutants 'killed' at least once: 3502
# Percentage of mutants 'killed' by any test: 93.36177019461476
# 426.0 ; 6.638229805385237
# Total number of mutants 'killed' at least once: 3532
# Percentage of mutants 'killed' by any test: 94.16155691815516
# 438.0 ; 5.838443081844844
# Total number of mutants 'killed' at least once: 3557
# Percentage of mutants 'killed' by any test: 94.82804585443881
# 457.0 ; 5.1719541455611875
# Total number of mutants 'killed' at least once: 3557
# Percentage of mutants 'killed' by any test: 94.82804585443881
# 477.0 ; 5.1719541455611875
# Total number of mutants 'killed' at least once: 3558
# Percentage of mutants 'killed' by any test: 94.85470541189017
# 502.0 ; 5.145294588109834
#
# Total number of mutants 'killed' at least once: 288
# Percentage of mutants 'killed' by any test: 5.758848230353929
# 8.0 ; 94.24115176964607
# Total number of mutants 'killed' at least once: 1139
# Percentage of mutants 'killed' by any test: 22.775444911017797
# 33.0 ; 77.2245550889822
# Total number of mutants 'killed' at least once: 1587
# Percentage of mutants 'killed' by any test: 31.733653269346128
# 49.0 ; 68.26634673065388
# Total number of mutants 'killed' at least once: 1849
# Percentage of mutants 'killed' by any test: 36.97260547890422
# 63.0 ; 63.02739452109578
# Total number of mutants 'killed' at least once: 2070
# Percentage of mutants 'killed' by any test: 41.39172165566887
# 77.0 ; 58.60827834433113
# Total number of mutants 'killed' at least once: 2356
# Percentage of mutants 'killed' by any test: 47.110577884423115
# 96.0 ; 52.889422115576885
# Total number of mutants 'killed' at least once: 2674
# Percentage of mutants 'killed' by any test: 53.46930613877225
# 121.0 ; 46.53069386122775
# Total number of mutants 'killed' at least once: 2873
# Percentage of mutants 'killed' by any test: 57.448510297940416
# 136.0 ; 42.551489702059584
# Total number of mutants 'killed' at least once: 3023
# Percentage of mutants 'killed' by any test: 60.44791041791642
# 161.0 ; 39.55208958208358
# Total number of mutants 'killed' at least once: 3123
# Percentage of mutants 'killed' by any test: 62.44751049790042
# 172.0 ; 37.55248950209958
# Total number of mutants 'killed' at least once: 3322
# Percentage of mutants 'killed' by any test: 66.42671465706859
# 191.0 ; 33.57328534293141
# Total number of mutants 'killed' at least once: 3420
# Percentage of mutants 'killed' by any test: 68.38632273545291
# 203.0 ; 31.613677264547093
# Total number of mutants 'killed' at least once: 3666
# Percentage of mutants 'killed' by any test: 73.30533893221356
# 228.0 ; 26.69466106778644
# Total number of mutants 'killed' at least once: 3864
# Percentage of mutants 'killed' by any test: 77.26454709058189
# 253.0 ; 22.735452909418115
# Total number of mutants 'killed' at least once: 3917
# Percentage of mutants 'killed' by any test: 78.32433513297342
# 278.0 ; 21.675664867026583
# Total number of mutants 'killed' at least once: 4018
# Percentage of mutants 'killed' by any test: 80.34393121375724
# 303.0 ; 19.656068786242756
# Total number of mutants 'killed' at least once: 4093
# Percentage of mutants 'killed' by any test: 81.84363127374526
# 324.0 ; 18.15636872625474
# Total number of mutants 'killed' at least once: 4171
# Percentage of mutants 'killed' by any test: 83.40331933613278
# 349.0 ; 16.596680663867218
# Total number of mutants 'killed' at least once: 4247
# Percentage of mutants 'killed' by any test: 84.92301539692062
# 374.0 ; 15.076984603079381
# Total number of mutants 'killed' at least once: 4319
# Percentage of mutants 'killed' by any test: 86.3627274545091
# 386.0 ; 13.637272545490902
# Total number of mutants 'killed' at least once: 4344
# Percentage of mutants 'killed' by any test: 86.86262747450509
# 393.0 ; 13.13737252549491
# Total number of mutants 'killed' at least once: 4420
# Percentage of mutants 'killed' by any test: 88.38232353529294
# 408.0 ; 11.61767646470706
# Total number of mutants 'killed' at least once: 4520
# Percentage of mutants 'killed' by any test: 90.38192361527695
# 433.0 ; 9.618076384723054
# Total number of mutants 'killed' at least once: 4568
# Percentage of mutants 'killed' by any test: 91.34173165366927
# 458.0 ; 8.658268346330729
# Total number of mutants 'killed' at least once: 4569
# Percentage of mutants 'killed' by any test: 91.3617276544691
# 483.0 ; 8.638272345530893
# Total number of mutants 'killed' at least once: 4621
# Percentage of mutants 'killed' by any test: 92.40151969606079
# 508.0 ; 7.598480303939212
# Total number of mutants 'killed' at least once: 4670
# Percentage of mutants 'killed' by any test: 93.38132373525295
# 522.0 ; 6.618676264747052
# Total number of mutants 'killed' at least once: 4695
# Percentage of mutants 'killed' by any test: 93.88122375524895
# 547.0 ; 6.1187762447510465
# Total number of mutants 'killed' at least once: 4720
# Percentage of mutants 'killed' by any test: 94.38112377524494
# 572.0 ; 5.618876224755056
#
# Total number of mutants 'killed' at least once: 1024
# Percentage of mutants 'killed' by any test: 15.997500390563973
# 17.0 ; 84.00249960943603
# Total number of mutants 'killed' at least once: 1381
# Percentage of mutants 'killed' by any test: 21.57475394469614
# 25.0 ; 78.42524605530386
# Total number of mutants 'killed' at least once: 2748
# Percentage of mutants 'killed' by any test: 42.93079206374004
# 65.0 ; 57.06920793625996
# Total number of mutants 'killed' at least once: 3337
# Percentage of mutants 'killed' by any test: 52.13247930010936
# 89.0 ; 47.86752069989064
# Total number of mutants 'killed' at least once: 4082
# Percentage of mutants 'killed' by any test: 63.77128573660366
# 129.0 ; 36.22871426339634
# Total number of mutants 'killed' at least once: 4398
# Percentage of mutants 'killed' by any test: 68.70801437275425
# 151.0 ; 31.29198562724575
# Total number of mutants 'killed' at least once: 4756
# Percentage of mutants 'killed' by any test: 74.30089048586159
# 175.0 ; 25.699109514138414
# Total number of mutants 'killed' at least once: 4955
# Percentage of mutants 'killed' by any test: 77.40977972191845
# 200.0 ; 22.590220278081546
# Total number of mutants 'killed' at least once: 5078
# Percentage of mutants 'killed' by any test: 79.33135447586315
# 219.0 ; 20.66864552413685
# Total number of mutants 'killed' at least once: 5171
# Percentage of mutants 'killed' by any test: 80.78425246055303
# 252.0 ; 19.215747539446966
# Total number of mutants 'killed' at least once: 5172
# Percentage of mutants 'killed' by any test: 80.7998750195282
# 263.0 ; 19.2001249804718
# Total number of mutants 'killed' at least once: 5351
# Percentage of mutants 'killed' by any test: 83.59631307608186
# 296.0 ; 16.403686923918144
# Total number of mutants 'killed' at least once: 5550
# Percentage of mutants 'killed' by any test: 86.70520231213872
# 336.0 ; 13.294797687861276
# Total number of mutants 'killed' at least once: 5664
# Percentage of mutants 'killed' by any test: 88.48617403530699
# 376.0 ; 11.513825964693012
# Total number of mutants 'killed' at least once: 5709
# Percentage of mutants 'killed' by any test: 89.1891891891892
# 401.0 ; 10.810810810810807
# Total number of mutants 'killed' at least once: 5831
# Percentage of mutants 'killed' by any test: 91.09514138415872
# 441.0 ; 8.904858615841277
# Total number of mutants 'killed' at least once: 5833
# Percentage of mutants 'killed' by any test: 91.12638650210904
# 449.0 ; 8.873613497890958
# Total number of mutants 'killed' at least once: 5876
# Percentage of mutants 'killed' by any test: 91.79815653804093
# 489.0 ; 8.201843461959072
# Total number of mutants 'killed' at least once: 5916
# Percentage of mutants 'killed' by any test: 92.42305889704734
# 523.0 ; 7.576941102952659
# Total number of mutants 'killed' at least once: 5990
# Percentage of mutants 'killed' by any test: 93.57912826120919
# 563.0 ; 6.420871738790808
# Total number of mutants 'killed' at least once: 6030
# Percentage of mutants 'killed' by any test: 94.20403062021559
# 603.0 ; 5.79596937978441
# Total number of mutants 'killed' at least once: 6070
# Percentage of mutants 'killed' by any test: 94.82893297922199
# 630.0 ; 5.171067020778011
# Total number of mutants 'killed' at least once: 6114
# Percentage of mutants 'killed' by any test: 95.51632557412904
# 670.0 ; 4.483674425870959
# Total number of mutants 'killed' at least once: 6154
# Percentage of mutants 'killed' by any test: 96.14122793313544
# 684.0 ; 3.85877206686456
# Total number of mutants 'killed' at least once: 6155
# Percentage of mutants 'killed' by any test: 96.1568504921106
# 696.0 ; 3.843149507889393
# Total number of mutants 'killed' at least once: 6156
# Percentage of mutants 'killed' by any test: 96.17247305108577
# 716.0 ; 3.827526948914226
# Total number of mutants 'killed' at least once: 6157
# Percentage of mutants 'killed' by any test: 96.18809561006093
# 754.0 ; 3.811904389939073
# Total number of mutants 'killed' at least once: 6162
# Percentage of mutants 'killed' by any test: 96.26620840493672
# 794.0 ; 3.7337915950632805
# Total number of mutants 'killed' at least once: 6163
# Percentage of mutants 'killed' by any test: 96.28183096391189
# 832.0 ; 3.7181690360881134
#
# Total number of mutants 'killed' at least once: 851
# Percentage of mutants 'killed' by any test: 8.863660035412977
# 14.0 ; 91.13633996458702
# Total number of mutants 'killed' at least once: 1834
# Percentage of mutants 'killed' by any test: 19.10217685657744
# 37.0 ; 80.89782314342256
# Total number of mutants 'killed' at least once: 2773
# Percentage of mutants 'killed' by any test: 28.882408082491406
# 70.0 ; 71.11759191750859
# Total number of mutants 'killed' at least once: 3643
# Percentage of mutants 'killed' by any test: 37.94396417039892
# 97.0 ; 62.05603582960108
# Total number of mutants 'killed' at least once: 3755
# Percentage of mutants 'killed' by any test: 39.11050932194563
# 103.0 ; 60.88949067805437
# Total number of mutants 'killed' at least once: 4076
# Percentage of mutants 'killed' by any test: 42.4539110509322
# 119.0 ; 57.5460889490678
# Total number of mutants 'killed' at least once: 4748
# Percentage of mutants 'killed' by any test: 49.453181960212476
# 148.0 ; 50.546818039787524
# Total number of mutants 'killed' at least once: 5300
# Percentage of mutants 'killed' by any test: 55.20258306426415
# 178.0 ; 44.79741693573585
# Total number of mutants 'killed' at least once: 5663
# Percentage of mutants 'killed' by any test: 58.98343922508072
# 195.0 ; 41.01656077491928
# Total number of mutants 'killed' at least once: 6061
# Percentage of mutants 'killed' by any test: 63.12884074575565
# 232.0 ; 36.87115925424435
# Total number of mutants 'killed' at least once: 6376
# Percentage of mutants 'killed' by any test: 66.40974898448079
# 250.0 ; 33.590251015519215
# Total number of mutants 'killed' at least once: 6621
# Percentage of mutants 'killed' by any test: 68.96156650348922
# 290.0 ; 31.038433496510777
# Total number of mutants 'killed' at least once: 6864
# Percentage of mutants 'killed' by any test: 71.49255285907718
# 312.0 ; 28.50744714092282
# Total number of mutants 'killed' at least once: 7189
# Percentage of mutants 'killed' by any test: 74.87761691490469
# 342.0 ; 25.122383085095308
# Total number of mutants 'killed' at least once: 7434
# Percentage of mutants 'killed' by any test: 77.42943443391313
# 369.0 ; 22.57056556608687
# Total number of mutants 'killed' at least once: 7670
# Percentage of mutants 'killed' by any test: 79.88751171752942
# 409.0 ; 20.11248828247058
# Total number of mutants 'killed' at least once: 7748
# Percentage of mutants 'killed' by any test: 80.69992709092803
# 429.0 ; 19.30007290907197
# Total number of mutants 'killed' at least once: 8025
# Percentage of mutants 'killed' by any test: 83.5850432246641
# 461.0 ; 16.414956775335895
# Total number of mutants 'killed' at least once: 8303
# Percentage of mutants 'killed' by any test: 86.48057494011042
# 501.0 ; 13.519425059889585
# Total number of mutants 'killed' at least once: 8384
# Percentage of mutants 'killed' by any test: 87.32423705863972
# 541.0 ; 12.675762941360276
# Total number of mutants 'killed' at least once: 8588
# Percentage of mutants 'killed' by any test: 89.44901572752838
# 581.0 ; 10.550984272471624
# Total number of mutants 'killed' at least once: 8628
# Percentage of mutants 'killed' by any test: 89.86563899593793
# 619.0 ; 10.134361004062072
# Total number of mutants 'killed' at least once: 8716
# Percentage of mutants 'killed' by any test: 90.78221018643892
# 653.0 ; 9.217789813561083
# Total number of mutants 'killed' at least once: 8796
# Percentage of mutants 'killed' by any test: 91.61545672325799
# 691.0 ; 8.384543276742008
# Total number of mutants 'killed' at least once: 8886
# Percentage of mutants 'killed' by any test: 92.55285907717946
# 731.0 ; 7.447140922820537
# Total number of mutants 'killed' at least once: 8887
# Percentage of mutants 'killed' by any test: 92.5632746588897
# 771.0 ; 7.436725341110304
# Total number of mutants 'killed' at least once: 9005
# Percentage of mutants 'killed' by any test: 93.79231330069786
# 811.0 ; 6.207686699302144
# Total number of mutants 'killed' at least once: 9044
# Percentage of mutants 'killed' by any test: 94.19852098739715
# 835.0 ; 5.801479012602854
# Total number of mutants 'killed' at least once: 9085
# Percentage of mutants 'killed' by any test: 94.62555983751693
# 875.0 ; 5.374440162483069
#
# Total number of mutants 'killed' at least once: 855
# Percentage of mutants 'killed' by any test: 6.679165690180455
# 13.0 ; 93.32083430981955
# Total number of mutants 'killed' at least once: 1476
# Percentage of mutants 'killed' by any test: 11.530349191469416
# 25.0 ; 88.46965080853059
# Total number of mutants 'killed' at least once: 3270
# Percentage of mutants 'killed' by any test: 25.544879306304196
# 65.0 ; 74.4551206936958
# Total number of mutants 'killed' at least once: 3393
# Percentage of mutants 'killed' by any test: 26.50574173892665
# 71.0 ; 73.49425826107336
# Total number of mutants 'killed' at least once: 4143
# Percentage of mutants 'killed' by any test: 32.364659011014766
# 99.0 ; 67.63534098898523
# Total number of mutants 'killed' at least once: 4916
# Percentage of mutants 'killed' by any test: 38.40324974611358
# 128.0 ; 61.59675025388642
# Total number of mutants 'killed' at least once: 5621
# Percentage of mutants 'killed' by any test: 43.91063198187641
# 160.0 ; 56.08936801812359
# Total number of mutants 'killed' at least once: 5895
# Percentage of mutants 'killed' by any test: 46.051089758612605
# 176.0 ; 53.948910241387395
# Total number of mutants 'killed' at least once: 6724
# Percentage of mutants 'killed' by any test: 52.52714631669401
# 216.0 ; 47.47285368330599
# Total number of mutants 'killed' at least once: 7321
# Percentage of mutants 'killed' by any test: 57.19084446527615
# 253.0 ; 42.80915553472385
# Total number of mutants 'killed' at least once: 7476
# Percentage of mutants 'killed' by any test: 58.40168736817436
# 270.0 ; 41.59831263182564
# Total number of mutants 'killed' at least once: 7680
# Percentage of mutants 'killed' by any test: 59.995312866182324
# 286.0 ; 40.004687133817676
# Total number of mutants 'killed' at least once: 8197
# Percentage of mutants 'killed' by any test: 64.03405983907507
# 323.0 ; 35.96594016092493
# Total number of mutants 'killed' at least once: 8599
# Percentage of mutants 'killed' by any test: 67.1744394969143
# 363.0 ; 32.8255605030857
# Total number of mutants 'killed' at least once: 8975
# Percentage of mutants 'killed' by any test: 70.11171002265448
# 403.0 ; 29.888289977345522
# Total number of mutants 'killed' at least once: 9254
# Percentage of mutants 'killed' by any test: 72.29122724787126
# 443.0 ; 27.708772752128738
# Total number of mutants 'killed' at least once: 9464
# Percentage of mutants 'killed' by any test: 73.93172408405594
# 477.0 ; 26.068275915944056
# Total number of mutants 'killed' at least once: 9907
# Percentage of mutants 'killed' by any test: 77.39239121943598
# 512.0 ; 22.60760878056402
# Total number of mutants 'killed' at least once: 10178
# Percentage of mutants 'killed' by any test: 79.50941332708382
# 547.0 ; 20.49058667291618
# Total number of mutants 'killed' at least once: 10451
# Percentage of mutants 'killed' by any test: 81.64205921412389
# 569.0 ; 18.35794078587611
# Total number of mutants 'killed' at least once: 10531
# Percentage of mutants 'killed' by any test: 82.2670103898133
# 609.0 ; 17.732989610186706
# Total number of mutants 'killed' at least once: 10613
# Percentage of mutants 'killed' by any test: 82.90758534489493
# 633.0 ; 17.092414655105074
# Total number of mutants 'killed' at least once: 10829
# Percentage of mutants 'killed' by any test: 84.59495351925631
# 672.0 ; 15.405046480743692
# Total number of mutants 'killed' at least once: 10949
# Percentage of mutants 'killed' by any test: 85.53238028279041
# 701.0 ; 14.467619717209587
# Total number of mutants 'killed' at least once: 11144
# Percentage of mutants 'killed' by any test: 87.05569877353332
# 741.0 ; 12.944301226466678
# Total number of mutants 'killed' at least once: 11184
# Percentage of mutants 'killed' by any test: 87.36817436137801
# 765.0 ; 12.63182563862199
# Total number of mutants 'killed' at least once: 11338
# Percentage of mutants 'killed' by any test: 88.5712053745801
# 804.0 ; 11.428794625419897
# Total number of mutants 'killed' at least once: 11374
# Percentage of mutants 'killed' by any test: 88.85243340364035
# 831.0 ; 11.147566596359653
# Total number of mutants 'killed' at least once: 11535
# Percentage of mutants 'killed' by any test: 90.11014764471525
# 859.0 ; 9.889852355284745
